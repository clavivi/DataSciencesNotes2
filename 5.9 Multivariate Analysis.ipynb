# %% [markdown]
# # Chapter 5 - Outlier Analysis
# ## Segment 9 - Multivariate analysis for outlier detection

# %%
import pandas as pd

import matplotlib.pyplot as plt
from pylab import rcParams
import seaborn as sb

# %%
# %matplotlib inline
rcParams['figure.figsize'] = 5, 4
sb.set_style('whitegrid')

# %% [markdown]
# ### Visually inspecting boxplots

# %%
df = pd.read_csv(filepath_or_buffer=r"C:\Users\Andre\Desktop\Projects\ecourses\PythonDataScienceEssentials\iris.data.csv", header=None, sep=',')

df.columns=['Sepal Length','Sepal Width','Petal Length','Petal Width', 'Species']

# %%
## Isolate data form target
data= df.iloc[:,0:4].values
target = df.iloc[:,4].values
    
df.head()

sb.boxplot(x='Species', y='Sepal Length', data=df, palette='hls')

# %% [markdown]
# ### Looking at the scatterplot matrix

# %%
sb.pairplot(df, hue='Species', palette='hls')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
g_sp = df.groupby('Species')
g_sp
